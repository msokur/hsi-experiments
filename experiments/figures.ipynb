# %%
import imageio as iio
import matplotlib.pyplot as plt
import os

plt.figure(dpi=300)
im = iio.imread('C:\\Users\\tkachenko\\Desktop\\HSI\\second paper\\pictures\\blood predictions for paper.png')
print(im[0, 1])
im[(im[:, :, 0] == 0) & (im[:, :, 1] == 0) & (im[:, :, 2] == 255)] = (68, 1, 84, 255) #change color from blue to violet for consistency

plt.imshow(im)
iio.imsave('C:\\Users\\tkachenko\\Desktop\\HSI\\second paper\\pictures\\blood predictions for paper_violet.png', im)
# Out:
# C:\Users\tkachenko\AppData\Local\Temp\ipykernel_25564\3514080133.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = iio.imread('C:\\Users\\tkachenko\\Desktop\\HSI\\second paper\\pictures\\blood predictions for paper.png')
# [ 87 106 122 255]
