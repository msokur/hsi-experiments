# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sensitivity_train = [0.9874200276899658, 0.9815417544424732, 0.9726658995212701, 0.9712476329754764, 0.9534205939575611, 0.9561662125269821, 0.945430506238035, 0.901885047678173]
specitivity_train = [0.9912998852495191, 0.9841335034405181, 0.9857955354583245, 0.9776283143817143, 0.9793063172388974, 0.9695928527299621, 0.9627514775022779, 0.9668698246162274]

sensitivity_test_all = [0.984841144372482, 0.9939441072976695, 0.9922102095976337, 0.986014075169565, 0.9876077311438625, 0.9697842827273191, 0.9803279106532714, 0.942985363863532]
specitivity_test_all = [0.9349517197711494, 0.926872978901427,0.9440254630153094, 0.9176522466701341, 0.9301010831957667, 0.92017367314172, 0.9230060378553177, 0.9446869134574071 ]
sensitivity_test_image = [0.3216, 0.5504, 0.4032, 0.3808, 0.312, 0.3712, 0.4256, 0.1264]

# %%
X = np.linspace(0, 0.7, 8)

plt.plot(X, sensitivity_train)
plt.plot(X, specitivity_train)
plt.plot(X, sensitivity_test_all)
plt.plot(X, specitivity_test_all)
#plt.plot(X, sensitivity_test_image)

plt.show()

# %%
print(np.argmax(sensitivity_train))
print(np.argmax(specitivity_train))
print(np.argmax(sensitivity_test_all))
print(np.argmax(specitivity_test_all))
print(np.argmax(sensitivity_test_image))
# Out:
# 0
# 0
# 1
# 7
# 1
