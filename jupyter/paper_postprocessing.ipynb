# %%
# !pip install --user imageio
# Out:
# Collecting imageio
#   Downloading imageio-2.22.2-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 4.4 MB/s eta 0:00:01
# Collecting pillow>=8.3.2
#   Downloading Pillow-9.2.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 69.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/sc.uni-leipzig.de/mi186veva/.local/lib/python3.8/site-packages (from imageio) (1.22.2)
# Installing collected packages: pillow, imageio
#   WARNING: The scripts imageio_download_bin and imageio_remove_bin are installed in '/home/sc.uni-leipzig.de/mi186veva/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed imageio-2.22.2 pillow-9.2.0

# %%
import numpy as np
import imageio as iio
import matplotlib.pyplot as plt
from scipy.ndimage import median_filter

# %%
img = iio.imread("cat.jpg")

white_fraction = 20 #percentage
black_fraction = 20 #percentage

def add_noise(img, color, fraction):
    
    for _ in range(int(img.shape[0] * img.shape[1] * fraction / 100)):
        
        x = np.random.randint(img.shape[0])
        y = np.random.randint(img.shape[1])
        img[x, y] = [color, color, color]
    
    return img

img_ = add_noise(img.copy(), 255, white_fraction)
img_ = add_noise(img_, 0, black_fraction)
img__ = img_.copy()
img__[..., 0] = median_filter(img_[..., 0], size=5)
img__[..., 1] = median_filter(img_[..., 1], size=5)
img__[..., 2] = median_filter(img_[..., 2], size=5)
# Out:
# <ipython-input-20-2a9ae1606205>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("cat.jpg")

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, dpi=200)
ax1.imshow(img)
ax2.imshow(img_)
ax3.imshow(img__)
ax1.set_title('a)', fontdict={'fontsize': 6}, y=-0.15)
ax2.set_title('b) ', fontdict={'fontsize': 6}, y=-0.15)
ax3.set_title('c)', fontdict={'fontsize': 6}, y=-0.15)
ax1.axis('off')
ax2.axis('off')
ax3.axis('off')
plt.savefig('cat_.png')
plt.show()

# %%
# !pip install --user prettytable
# Out:
# Collecting prettytable
#   Downloading prettytable-3.4.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: wcwidth in /software/jupyterlab/opt/anaconda3/envs/jupyterlab/lib/python3.8/site-packages (from prettytable) (0.2.5)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.4.1

# %%
from prettytable import PrettyTable

def makePrettyTable(table_col1, table_col2, table_col3):
    table = PrettyTable()
    table.add_column("Column-1", table_col1)
    table.add_column("Column-2", table_col2)
    table.add_column("Column-3", table_col3)
    return table

# %%
makePrettyTable([0, 1, 1], [2, 2, 2], [3, 3, 3])
# Out:
# +----------+----------+----------+
# | Column-1 | Column-2 | Column-3 |
# +----------+----------+----------+
# |    0     |    2     |    3     |
# |    1     |    2     |    3     |
# |    1     |    2     |    3     |
# +----------+----------+----------+

# %%
import numpy as np
import matplotlib.pyplot as plt

predictions = np.load('/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/test/CV_3d_inception/cp-0036/predictions_whole.npy', allow_pickle=True)

# %%
images = []

for i in range(3):
    images.append(np.reshape(predictions[10+i]['predictions'], (480, 640)))

# %%
ig, (ax1, ax2, ax3) = plt.subplots(1, 3, dpi=200)
ax1.imshow(images[0].T)
ax2.imshow(images[1].T)
ax3.imshow(images[2].T)
#ax1.set_title('a)', fontdict={'fontsize': 6}, y=-0.15)
#ax2.set_title('b) ', fontdict={'fontsize': 6}, y=-0.15)
#ax3.set_title('c)', fontdict={'fontsize': 6}, y=-0.15)
ax1.axis('off')
ax2.axis('off')
ax3.axis('off')
plt.savefig('predictions_of_3_patients.png')
plt.show()

# %%
import numpy as np

arr = np.random.randint(20, size=(10, 10))
arr
# Out:
# array([[ 4,  0, 18,  0,  2,  0, 13, 14, 13,  8],
#        [ 0,  0,  1,  0, 16, 13,  4, 12, 16, 13],
#        [ 5, 15, 14, 19, 14, 10, 19, 14, 17, 18],
#        [10,  7,  5, 14, 15,  7,  9,  8, 13, 16],
#        [13, 18, 18,  6, 18, 19,  2,  3,  1,  5],
#        [ 1, 11, 19, 19,  4,  9,  0,  0,  4,  0],
#        [10, 13, 15, 19,  1,  3,  0,  9, 16,  5],
#        [ 7,  9,  2, 18, 13,  0,  7,  0, 16,  5],
#        [18,  2,  4,  8, 11,  8,  7,  0, 17,  1],
#        [ 1, 19, 10,  1,  5,  6,  7, 16,  5,  1]])
