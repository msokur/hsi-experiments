# %%
import tensorflow as tf

# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
import config
# Out:
# paths from config ['/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/utils', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/data_utils/data_loaders', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/models', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/trainers', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/data_utils', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/utils', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/data_utils/data_loaders', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/models', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/trainers', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/data_utils', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/utils', '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/jupyter', '/software/jupyterlab/opt/anaconda3/envs/tensorflow/lib/python38.zip', '/software/jupyterlab/opt/anaconda3/en
# ...

# %%
from glob import glob

# %%
def print_model_summary(path):
    prefix = '/home/sc.uni-leipzig.de/mi186veva/hsi-experiments/logs'
    custom_objects = {'f1_m': config.CUSTOM_OBJECTS}
    print(path)
    
    test_model_path = glob(os.path.join(prefix, path, '*/'))[0]
    #print(test_model_path)
    checkpoints_path = glob(os.path.join(test_model_path, 'checkpoints', '*'))[0]
    
    model = tf.keras.models.load_model(checkpoints_path, custom_objects=custom_objects)
    model.summary()
    
    
paths = ['CV_3d_inception',
        'CV_3d_inception_exclude1_all',
        'CV_3d_inception_svn_every_third',
        'CV_3d_svn_every_third',
        'CV_3d_sample_weights_every_third',
        'CV_3d_every_third',
        'CV_3d_bg_every_third',
        'CV_3d_inception_exclude1_every_third',
        'inception_l2_norm_all_data',
        'CV_3d',
        'CV_best_4pat',
        'CV_best_raw',
        'CV_aug',
        'CV_combi_WRA_50max_8inc_30epochs_1pat',
        'CV_combi_WRA_fixed_preproc_smaller_model_50max_20epochs_1pat',
        'CV_2blocks',
        'CV_rms']

for path in paths:
    print_model_summary(path)
# Out:
# CV_3d_inception
# /home/sc.uni-leipzig.de/mi186veva/hsi-experiments/logs/CV_3d_inception/3d_24_25_26_27/
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# title (InputLayer)              [(None, 5, 5, 92)]   0
# __________________________________________________________________________________________________
# tf.expand_dims_6 (TFOpLambda)   (None, 5, 5, 92, 1)  0           title[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 5, 5, 92, 48) 96          tf.expand_dims_6[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 5, 5, 92, 8)  16          tf.expand_dims_6[0][0]
# ...
